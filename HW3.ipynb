# %% [markdown]
# ### <p style="text-align: right;"> &#9989; **Yating Liao** </p>
# HW3
# ISE 599 Deep Learning

# %% [markdown]
# 1. Open the library and get the player image

# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt

image= cv2.imread('D:\Caroline\Documents\Graduate\ISE 599  Deep Learning\player1.png')
plt.imshow(image)

# %% [markdown]
# 2. Use the cvtColor function to convert the image to grayscale, then display it

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)

# %% [markdown]
# 3. Load the Haar cascade face classifier xml file.

# %%
haar_cascade = cv2.CascadeClassifier('D:\Caroline\Documents\Graduate\ISE 599  Deep Learning\haarcascade_frontalface_default.xml')

# %% [markdown]
# 4. Get coordinates for the player face in the image

# %%
faces_cordinates = haar_cascade.detectMultiScale(image_gray,scaleFactor = 1.3,minNeighbors = 7)

# %% [markdown]
# 5. Use the rectangle function to draw a rectangle on the face

# %%
for (p,q,r,s) in faces_cordinates:
    cv2.rectangle(image, (p, q), (p+r, q+s), (255,255,0), 2)
plt.imshow(image)

# %% [markdown]
# 6. Convert the image color space BGR to RGB

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %% [markdown]
# 7. Display the image with the bounding box

# %%
plt.imshow(image_rgb)

# %% [markdown]
# 8. Repeat these steps to detect the faces on the file players.png

# %%
# get the players image
image2 = cv2.imread("D:\Caroline\Documents\Graduate\ISE 599  Deep Learning\players.jpeg")
plt.imshow(image2)

# %%
# Use the cvtColor function to convert the image to grayscale, then display it
image_gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray2)

# %%
# Get coordinates for the player face in the image
faces_cordinates2 = haar_cascade.detectMultiScale(image_gray2)

# %%
# Use the rectangle function to draw a rectangle on the face
for (p,q,r,s) in faces_cordinates2:
    cv2.rectangle(image2, (p, q), (p+r, q+s), (255,255,0), 2)

# %%
# Convert the image color space BGR to RGB
image_rgb2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb2)
